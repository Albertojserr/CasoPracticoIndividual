# %%
import os
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torchvision
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score
import random
import numpy as np
from numpy import vstack
from numpy import argmax
import matplotlib.pyplot as plt

# %%
## Step 1: Create a dataloader for Pytorch
class CatDogDataset(Dataset):
    def __init__(self, train_dir, img_list, transform = None):
        self.train_dir = train_dir
        self.transform = transform
        self.images = img_list
        
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, index):
        image_path = os.path.join(self.train_dir, self.images[index])
        label = self.images[index].split(".")[0]
        label = 0 if label == 'cat' else 1
        img = np.array(Image.open(image_path))
        if self.transform:
            img = self.transform(img)
        return img, torch.tensor(label)

# %%
## Step 2: Create training dataset
data_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((256, 256),antialias=None),
    transforms.ColorJitter(),
    transforms.RandomCrop(224),
    transforms.RandomHorizontalFlip()
])

# Create dataloaders
train_dir = 'train/'
images_paths = os.listdir(train_dir)
random.shuffle(images_paths)
train_img_list = images_paths[0:20000]
val_img_list = images_paths[20000:25000]
train_img_list = images_paths[0:2000]
val_img_list = images_paths[2000:2500]
train_dataset = CatDogDataset(train_dir, train_img_list, transform = data_transform)
val_dataset = CatDogDataset(train_dir, val_img_list, transform = data_transform)
train_dataloader = DataLoader(train_dataset, batch_size = 64, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size = 64, shuffle=False)

# Visualize images in the dataset
samples, labels = next(iter(train_dataloader))
plt.figure(figsize=(16,32))
grid_imgs = torchvision.utils.make_grid(samples[:32])
np_grid_imgs = grid_imgs.numpy()
# in tensor, image is (batch, width, height), so you have to transpose it to (width, height, batch) in numpy to show it.
plt.imshow(np.transpose(np_grid_imgs, (1,2,0)))
plt.show()

# %%
## Step 3: Define Deep Learning model
class scratch_nn(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=100, kernel_size=5, stride=1, padding=0)
        self.conv2 = nn.Conv2d(100, 200, 3, stride=1, padding=0)
        self.conv3 = nn.Conv2d(200, 400, 3, stride=1, padding=0)
        self.mpool = nn.MaxPool2d(kernel_size=3)
        self.relu = nn.ReLU()
        self.linear1 = nn.Linear(19600,1024)
        self.linear2 = nn.Linear(1024,512)
        self.linear3 = nn.Linear(512,2)
        self.classifier = nn.Softmax(dim=1)
        
    def forward(self,x):
        x = self.mpool( self.relu(self.conv1(x)) )
        x = self.mpool( self.relu(self.conv2(x)) )
        x = self.mpool( self.relu(self.conv3(x)) )
        x = torch.flatten(x, start_dim=1)
        x = self.linear1(x)
        x = self.linear2(x)
        x = self.linear3(x)
        x = self.classifier(x)
        return x

# %%
## Step 4: Define train_step and predict functions
def train_step(train_loader, model, optimizer, criterion, device):
    # define the optimization
    avg_loss = []
    predictions, actuals = list(), list()
    # enumerate mini batches
    for i, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        # clear the gradients
        optimizer.zero_grad()
        # compute the model output
        yhat = model(inputs)
        # calculate loss
        loss = criterion(yhat, targets)
        # credit assignment
        loss.backward()
        # update model weights
        optimizer.step()
        avg_loss.append(loss.item())
        # Get accruacy
        actual = targets.cpu().numpy()
        yhat = argmax(yhat.detach().cpu().numpy(), axis=1)
        # reshape for stacking
        actual = actual.reshape((len(actual), 1))
        yhat = yhat.reshape((len(yhat), 1))
        # store
        predictions.append(yhat)
        actuals.append(actual)
    
    predictions, actuals = vstack(predictions), vstack(actuals)
    # calculate accuracy
    acc = accuracy_score(actuals, predictions)
    return sum(avg_loss)/len(avg_loss), acc

# evaluate the model
def evaluation_step(val_loader, model, criterion, device):
    avg_loss = []
    predictions, actuals = list(), list()
    for i, (inputs, targets) in enumerate(val_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        # evaluate the model on the test set
        yhat = model(inputs)
        loss = criterion(yhat, targets)
        avg_loss.append(loss.item())
        # retrieve numpy array
        yhat = yhat.detach().cpu().numpy()
        actual = targets.cpu().numpy()
        # convert to class labels
        yhat = argmax(yhat, axis=1)
        # reshape for stacking
        actual = actual.reshape((len(actual), 1))
        yhat = yhat.reshape((len(yhat), 1))
        # store
        predictions.append(yhat)
        actuals.append(actual)

    predictions, actuals = vstack(predictions), vstack(actuals)
    # calculate accuracy
    acc = accuracy_score(actuals, predictions)
    return sum(avg_loss)/len(avg_loss), acc

# %%
## Step 5: Define main train function
def train(model, train_dataloader, val_dataloader, optimizer, criterion, device):
    num_epoch = 150
    train_loss_list, train_acc_list, val_loss_list, val_acc_list = [], [], [], []
    for epoch in range(1, num_epoch + 1):
        train_loss, train_acc = train_step(train_dataloader, model, optimizer, criterion, device)
        train_loss_list.append(train_loss)
        train_acc_list.append(train_acc*100)
        print(f"Train: Loss at epoch {epoch} is {train_loss} and accuracy is {train_acc*100}%")
        val_loss, val_acc = evaluation_step(val_dataloader, model, criterion, device)
        val_loss_list.append(val_loss)
        val_acc_list.append(val_acc*100)
        print(f"Validation: Loss at epoch {epoch} is {val_loss} and accuracy is {val_acc*100}%")
        torch.save(model.state_dict(), model_file_name)
    return model, train_loss_list, train_acc_list, val_loss_list, val_acc_list

# %%
# Step 6: Training parameters, model declaration and training/validation process
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = scratch_nn()
model = model.to(device)

lr = 0.001
weight_dec = 0.001
model_file_name = "dogs_cats_model.pth"
optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_dec)
criterion = nn.CrossEntropyLoss()
model, train_loss, train_acc, val_loss, val_acc = train(model, train_dataloader, val_dataloader, optimizer, criterion, device)
# Out:
# Train: Loss at epoch 1 is 0.7031650301069021 and accuracy is 50.1%
# Validation: Loss at epoch 1 is 0.6920978277921677 and accuracy is 57.199999999999996%
# Train: Loss at epoch 2 is 0.6893759090453386 and accuracy is 55.15%
# Validation: Loss at epoch 2 is 0.6933397948741913 and accuracy is 50.6%
# Train: Loss at epoch 3 is 0.6746873073279858 and accuracy is 56.3%
# Validation: Loss at epoch 3 is 0.6764189377427101 and accuracy is 57.8%
# Train: Loss at epoch 4 is 0.6567842196673155 and accuracy is 60.75000000000001%
# Validation: Loss at epoch 4 is 0.6479990780353546 and accuracy is 63.0%
# Train: Loss at epoch 5 is 0.6581855714321136 and accuracy is 61.050000000000004%
# Validation: Loss at epoch 5 is 0.6508930251002312 and accuracy is 63.6%
# Train: Loss at epoch 6 is 0.6489099320024252 and accuracy is 62.150000000000006%
# Validation: Loss at epoch 6 is 0.6826266050338745 and accuracy is 59.8%
# Train: Loss at epoch 7 is 0.64041318744421 and accuracy is 63.3%
# Validation: Loss at epoch 7 is 0.6382918357849121 and accuracy is 64.0%
# Train: Loss at epoch 8 is 0.6295539867132902 and accuracy is 64.25%
# Validation: Loss at epoch 8 is 0.6727798283100128 and accuracy is 56.39999999999999%
# Train: Loss at epoch 9 is 0.6367717254906893 and accuracy is 63.05%
# Validation: Loss at epoch 9 is 0.6399757340550423 and accuracy is 64.2%
# Train: Loss at epoch 10 is 0.6208154186606407 and accuracy is 66.75%
# Validation: Loss at epoch 10 is 0.6307142972946167 and accuracy is 66.0%
# Train: Loss at epoch 11 is 0.6092815548181534 and accuracy is 67.60000000000001%
# Validation: Loss at epoch 11 is 0.6197492256760597 and accuracy is 67.2%
# Train: Loss at epoch 12 is 0.6112154293805361 and accuracy is 68.55%
# Validation: Loss at epoch 12 is 0.6260907500982285 and accuracy is 66.2%
# Train: Loss at epoch 13 is 0.594810388982296 and accuracy is 70.05%
# Validation: Loss at epoch 13 is 0.6674171984195709 and accuracy is 62.0%
# Train: Loss at epoch 14 is 0.5894454047083855 and accuracy is 70.65%
# Validation: Loss at epoch 14 is 0.584664024412632 and accuracy is 70.6%
# Train: Loss at epoch 15 is 0.5861109104007483 and accuracy is 70.89999999999999%
# Validation: Loss at epoch 15 is 0.6313335821032524 and accuracy is 66.0%
# Train: Loss at epoch 16 is 0.6068579126149416 and accuracy is 67.95%
# Validation: Loss at epoch 16 is 0.6110203638672829 and accuracy is 67.80000000000001%
# Train: Loss at epoch 17 is 0.6004249975085258 and accuracy is 69.25%
# Validation: Loss at epoch 17 is 0.5910314992070198 and accuracy is 71.2%
# Train: Loss at epoch 18 is 0.5791938472539186 and accuracy is 72.15%
# Validation: Loss at epoch 18 is 0.6033619567751884 and accuracy is 68.2%
# Train: Loss at epoch 19 is 0.5778011130169034 and accuracy is 72.3%
# Validation: Loss at epoch 19 is 0.5981106758117676 and accuracy is 70.39999999999999%
# Train: Loss at epoch 20 is 0.5749730756506324 and accuracy is 72.8%
# Validation: Loss at epoch 20 is 0.6181141212582588 and accuracy is 66.2%
# Train: Loss at epoch 21 is 0.5793824475258589 and accuracy is 71.75%
# Validation: Loss at epoch 21 is 0.5790746808052063 and accuracy is 72.6%
# Train: Loss at epoch 22 is 0.5468321479856968 and accuracy is 75.44999999999999%
# Validation: Loss at epoch 22 is 0.5984656065702438 and accuracy is 69.6%
# Train: Loss at epoch 23 is 0.5488913152366877 and accuracy is 75.05%
# Validation: Loss at epoch 23 is 0.663990281522274 and accuracy is 62.4%
# Train: Loss at epoch 24 is 0.5585802858695388 and accuracy is 74.0%
# Validation: Loss at epoch 24 is 0.5894716456532478 and accuracy is 69.8%
# Train: Loss at epoch 25 is 0.5477813398465514 and accuracy is 75.4%
# Validation: Loss at epoch 25 is 0.5534845367074013 and accuracy is 75.2%
# Train: Loss at epoch 26 is 0.5363599788397551 and accuracy is 76.6%
# Validation: Loss at epoch 26 is 0.5806437358260155 and accuracy is 71.6%
# Train: Loss at epoch 27 is 0.5352578992024064 and accuracy is 75.55%
# Validation: Loss at epoch 27 is 0.5396710373461246 and accuracy is 78.0%
# Train: Loss at epoch 28 is 0.5320775294676423 and accuracy is 76.5%
# Validation: Loss at epoch 28 is 0.5580065548419952 and accuracy is 72.2%
# Train: Loss at epoch 29 is 0.5162333641201258 and accuracy is 78.3%
# Validation: Loss at epoch 29 is 0.5573899522423744 and accuracy is 74.4%
# Train: Loss at epoch 30 is 0.6507046688348055 and accuracy is 64.0%
# Validation: Loss at epoch 30 is 0.5840624570846558 and accuracy is 70.39999999999999%
# Train: Loss at epoch 31 is 0.5713091976940632 and accuracy is 72.35000000000001%
# Validation: Loss at epoch 31 is 0.5839469358325005 and accuracy is 70.8%
# Train: Loss at epoch 32 is 0.5503408294171095 and accuracy is 75.3%
# Validation: Loss at epoch 32 is 0.5398112758994102 and accuracy is 77.2%
# Train: Loss at epoch 33 is 0.5222093351185322 and accuracy is 78.55%
# Validation: Loss at epoch 33 is 0.5747828111052513 and accuracy is 71.6%
# Train: Loss at epoch 34 is 0.5164268296211958 and accuracy is 78.7%
# Validation: Loss at epoch 34 is 0.5388445220887661 and accuracy is 76.6%
# Train: Loss at epoch 35 is 0.5112438797950745 and accuracy is 79.35%
# Validation: Loss at epoch 35 is 0.5372563414275646 and accuracy is 76.8%
# Train: Loss at epoch 36 is 0.5150790195912123 and accuracy is 79.10000000000001%
# Validation: Loss at epoch 36 is 0.5578420832753181 and accuracy is 73.6%
# Train: Loss at epoch 37 is 0.5095944963395596 and accuracy is 78.95%
# Validation: Loss at epoch 37 is 0.5470290370285511 and accuracy is 75.2%
# Train: Loss at epoch 38 is 0.5231405980885029 and accuracy is 78.3%
# Validation: Loss at epoch 38 is 0.5551428757607937 and accuracy is 75.8%
# Train: Loss at epoch 39 is 0.5023683998733759 and accuracy is 80.05%
# Validation: Loss at epoch 39 is 0.5402757562696934 and accuracy is 77.4%
# Train: Loss at epoch 40 is 0.5030413549393415 and accuracy is 79.75%
# Validation: Loss at epoch 40 is 0.5416189432144165 and accuracy is 75.4%
# Train: Loss at epoch 41 is 0.5001678476110101 and accuracy is 80.45%
# Validation: Loss at epoch 41 is 0.5422414168715477 and accuracy is 75.6%
# Train: Loss at epoch 42 is 0.49473867658525705 and accuracy is 81.2%
# Validation: Loss at epoch 42 is 0.5342398658394814 and accuracy is 77.0%
# Train: Loss at epoch 43 is 0.510218364186585 and accuracy is 79.85%
# Validation: Loss at epoch 43 is 0.5763855203986168 and accuracy is 73.2%
# Train: Loss at epoch 44 is 0.5257976176217198 and accuracy is 77.3%
# Validation: Loss at epoch 44 is 0.5283705219626427 and accuracy is 77.2%
# Train: Loss at epoch 45 is 0.5137774674221873 and accuracy is 78.85%
# Validation: Loss at epoch 45 is 0.5672484785318375 and accuracy is 73.2%
# Train: Loss at epoch 46 is 0.5126019576564431 and accuracy is 78.25%
# Validation: Loss at epoch 46 is 0.5376895219087601 and accuracy is 78.60000000000001%
# Train: Loss at epoch 47 is 0.4896970959380269 and accuracy is 81.39999999999999%
# Validation: Loss at epoch 47 is 0.5278299227356911 and accuracy is 77.60000000000001%
# Train: Loss at epoch 48 is 0.47605439741164446 and accuracy is 82.85%
# Validation: Loss at epoch 48 is 0.5343577638268471 and accuracy is 75.6%
# Train: Loss at epoch 49 is 0.48978712782263756 and accuracy is 81.6%
# Validation: Loss at epoch 49 is 0.5220551490783691 and accuracy is 78.60000000000001%
# Train: Loss at epoch 50 is 0.4843245027586818 and accuracy is 82.6%
# Validation: Loss at epoch 50 is 0.5183616951107979 and accuracy is 77.8%
# Train: Loss at epoch 51 is 0.480892539024353 and accuracy is 83.2%
# Validation: Loss at epoch 51 is 0.5179319605231285 and accuracy is 77.2%
# Train: Loss at epoch 52 is 0.47799685038626194 and accuracy is 82.69999999999999%
# Validation: Loss at epoch 52 is 0.5546809919178486 and accuracy is 73.6%
# Train: Loss at epoch 53 is 0.49586338084191084 and accuracy is 80.4%
# Validation: Loss at epoch 53 is 0.5329520590603352 and accuracy is 76.2%
# Train: Loss at epoch 54 is 0.5039053065702319 and accuracy is 80.2%
# Validation: Loss at epoch 54 is 0.5447445660829544 and accuracy is 75.2%
# Train: Loss at epoch 55 is 0.48011483531445265 and accuracy is 82.19999999999999%
# Validation: Loss at epoch 55 is 0.5103417299687862 and accuracy is 79.2%
# Train: Loss at epoch 56 is 0.47434642538428307 and accuracy is 82.89999999999999%
# Validation: Loss at epoch 56 is 0.5377303697168827 and accuracy is 76.6%
# Train: Loss at epoch 57 is 0.4962690006941557 and accuracy is 80.25%
# Validation: Loss at epoch 57 is 0.5248211733996868 and accuracy is 78.4%
# Train: Loss at epoch 58 is 0.4905791599303484 and accuracy is 81.0%
# Validation: Loss at epoch 58 is 0.5096994861960411 and accuracy is 80.2%
# Train: Loss at epoch 59 is 0.4792152987793088 and accuracy is 82.55%
# Validation: Loss at epoch 59 is 0.5687244050204754 and accuracy is 73.8%
# Train: Loss at epoch 60 is 0.48452430311590433 and accuracy is 81.89999999999999%
# Validation: Loss at epoch 60 is 0.5033977665007114 and accuracy is 80.4%
# Train: Loss at epoch 61 is 0.46928884740918875 and accuracy is 84.05%
# Validation: Loss at epoch 61 is 0.513002548366785 and accuracy is 78.4%
# Train: Loss at epoch 62 is 0.46580127347260714 and accuracy is 84.05%
# Validation: Loss at epoch 62 is 0.5068231895565987 and accuracy is 80.2%
# Train: Loss at epoch 63 is 0.4734811196103692 and accuracy is 83.3%
# Validation: Loss at epoch 63 is 0.5141007490456104 and accuracy is 78.4%
# Train: Loss at epoch 64 is 0.47341701574623585 and accuracy is 83.8%
# Validation: Loss at epoch 64 is 0.5416189208626747 and accuracy is 75.4%
# Train: Loss at epoch 65 is 0.46770756505429745 and accuracy is 84.55%
# Validation: Loss at epoch 65 is 0.5918402448296547 and accuracy is 70.19999999999999%
# Train: Loss at epoch 66 is 0.4766268329694867 and accuracy is 82.85%
# Validation: Loss at epoch 66 is 0.5086051821708679 and accuracy is 79.2%
# Train: Loss at epoch 67 is 0.47712091635912657 and accuracy is 82.8%
# Validation: Loss at epoch 67 is 0.5159274451434612 and accuracy is 79.80000000000001%
# Train: Loss at epoch 68 is 0.4596648411825299 and accuracy is 85.2%
# Validation: Loss at epoch 68 is 0.5282947383821011 and accuracy is 77.8%
# Train: Loss at epoch 69 is 0.46652289666235447 and accuracy is 83.95%
# Validation: Loss at epoch 69 is 0.5239543914794922 and accuracy is 78.2%
# Train: Loss at epoch 70 is 0.47178418189287186 and accuracy is 83.35000000000001%
# Validation: Loss at epoch 70 is 0.5337932482361794 and accuracy is 77.0%
# Train: Loss at epoch 71 is 0.47749308962374926 and accuracy is 82.65%
# Validation: Loss at epoch 71 is 0.5327023454010487 and accuracy is 77.4%
# Train: Loss at epoch 72 is 0.4934001360088587 and accuracy is 81.25%
# Validation: Loss at epoch 72 is 0.5217952840030193 and accuracy is 78.2%
# Train: Loss at epoch 73 is 0.4763434827327728 and accuracy is 83.05%
# Validation: Loss at epoch 73 is 0.5074215866625309 and accuracy is 79.0%
# Train: Loss at epoch 74 is 0.4743486298248172 and accuracy is 83.05%
# Validation: Loss at epoch 74 is 0.5305937938392162 and accuracy is 76.6%
# Train: Loss at epoch 75 is 0.4613836370408535 and accuracy is 84.65%
# Validation: Loss at epoch 75 is 0.4787630960345268 and accuracy is 82.6%
# Train: Loss at epoch 76 is 0.4469336150214076 and accuracy is 86.4%
# Validation: Loss at epoch 76 is 0.4801030531525612 and accuracy is 83.6%
# Train: Loss at epoch 77 is 0.4709829417988658 and accuracy is 83.3%
# Validation: Loss at epoch 77 is 0.5183326452970505 and accuracy is 77.8%
# Train: Loss at epoch 78 is 0.45457112044095993 and accuracy is 84.95%
# Validation: Loss at epoch 78 is 0.5109759829938412 and accuracy is 79.80000000000001%
# Train: Loss at epoch 79 is 0.4538695914670825 and accuracy is 85.65%
# Validation: Loss at epoch 79 is 0.5065008513629436 and accuracy is 80.2%
# Train: Loss at epoch 80 is 0.4406095826998353 and accuracy is 87.64999999999999%
# Validation: Loss at epoch 80 is 0.5942082479596138 and accuracy is 70.19999999999999%
# Train: Loss at epoch 81 is 0.46711104549467564 and accuracy is 83.7%
# Validation: Loss at epoch 81 is 0.4896012209355831 and accuracy is 80.60000000000001%
# Train: Loss at epoch 82 is 0.45522480364888906 and accuracy is 85.45%
# Validation: Loss at epoch 82 is 0.49155717715620995 and accuracy is 81.6%
# Train: Loss at epoch 83 is 0.45541631430387497 and accuracy is 85.25%
# Validation: Loss at epoch 83 is 0.4855453073978424 and accuracy is 82.39999999999999%
# Train: Loss at epoch 84 is 0.4458403242751956 and accuracy is 86.25%
# Validation: Loss at epoch 84 is 0.5151815377175808 and accuracy is 78.0%
# Train: Loss at epoch 85 is 0.4689419185742736 and accuracy is 84.1%
# Validation: Loss at epoch 85 is 0.5236494690179825 and accuracy is 78.2%
# Train: Loss at epoch 86 is 0.44184848573058844 and accuracy is 86.95%
# Validation: Loss at epoch 86 is 0.5036733448505402 and accuracy is 80.2%
# Train: Loss at epoch 87 is 0.4401994114741683 and accuracy is 86.75%
# Validation: Loss at epoch 87 is 0.4929829612374306 and accuracy is 81.6%
# Train: Loss at epoch 88 is 0.4359733182936907 and accuracy is 87.0%
# Validation: Loss at epoch 88 is 0.487553495913744 and accuracy is 82.6%
# Train: Loss at epoch 89 is 0.44214276876300573 and accuracy is 86.3%
# Validation: Loss at epoch 89 is 0.4927678629755974 and accuracy is 81.6%
# Train: Loss at epoch 90 is 0.4575279029086232 and accuracy is 85.0%
# Validation: Loss at epoch 90 is 0.4903629422187805 and accuracy is 82.19999999999999%
# Train: Loss at epoch 91 is 0.44521251134574413 and accuracy is 86.55000000000001%
# Validation: Loss at epoch 91 is 0.5096804723143578 and accuracy is 79.60000000000001%
# Train: Loss at epoch 92 is 0.44263069797307253 and accuracy is 86.15%
# Validation: Loss at epoch 92 is 0.49968256056308746 and accuracy is 81.0%
# Train: Loss at epoch 93 is 0.44760070089250803 and accuracy is 86.45%
# Validation: Loss at epoch 93 is 0.49276043847203255 and accuracy is 82.0%
# Train: Loss at epoch 94 is 0.44819752406328917 and accuracy is 86.1%
# Validation: Loss at epoch 94 is 0.4960741512477398 and accuracy is 80.60000000000001%
# Train: Loss at epoch 95 is 0.4391896054148674 and accuracy is 87.7%
# Validation: Loss at epoch 95 is 0.4882006086409092 and accuracy is 81.39999999999999%
# Train: Loss at epoch 96 is 0.42403719201684 and accuracy is 88.25%
# Validation: Loss at epoch 96 is 0.4783807694911957 and accuracy is 82.19999999999999%
# Train: Loss at epoch 97 is 0.4229971282184124 and accuracy is 88.6%
# Validation: Loss at epoch 97 is 0.4886627607047558 and accuracy is 81.0%
# Train: Loss at epoch 98 is 0.43549364246428013 and accuracy is 87.45%
# Validation: Loss at epoch 98 is 0.49328211694955826 and accuracy is 80.80000000000001%
# Train: Loss at epoch 99 is 0.4377111615613103 and accuracy is 87.35000000000001%
# Validation: Loss at epoch 99 is 0.5157025307416916 and accuracy is 79.2%
# Train: Loss at epoch 100 is 0.45366566721349955 and accuracy is 85.5%
# Validation: Loss at epoch 100 is 0.4809277169406414 and accuracy is 83.0%
# Train: Loss at epoch 101 is 0.4451100705191493 and accuracy is 86.9%
# Validation: Loss at epoch 101 is 0.5144566670060158 and accuracy is 78.60000000000001%
# Train: Loss at epoch 102 is 0.4250259371474385 and accuracy is 88.6%
# Validation: Loss at epoch 102 is 0.5289768204092979 and accuracy is 77.2%
# Train: Loss at epoch 103 is 0.43279581889510155 and accuracy is 87.94999999999999%
# Validation: Loss at epoch 103 is 0.48415714129805565 and accuracy is 81.8%
# Train: Loss at epoch 104 is 0.42321951873600483 and accuracy is 88.55%
# Validation: Loss at epoch 104 is 0.48533423617482185 and accuracy is 81.39999999999999%
# Train: Loss at epoch 105 is 0.42588553577661514 and accuracy is 88.6%
# Validation: Loss at epoch 105 is 0.5022689439356327 and accuracy is 80.0%
# Train: Loss at epoch 106 is 0.4381019016727805 and accuracy is 87.3%
# Validation: Loss at epoch 106 is 0.5093392059206963 and accuracy is 80.2%
# Train: Loss at epoch 107 is 0.424259009771049 and accuracy is 88.35%
# Validation: Loss at epoch 107 is 0.49255820736289024 and accuracy is 82.0%
# Train: Loss at epoch 108 is 0.4362292718142271 and accuracy is 87.2%
# Validation: Loss at epoch 108 is 0.5059927999973297 and accuracy is 80.0%
# Train: Loss at epoch 109 is 0.43655777629464865 and accuracy is 87.25%
# Validation: Loss at epoch 109 is 0.47559426724910736 and accuracy is 83.6%
# Train: Loss at epoch 110 is 0.43876256700605154 and accuracy is 86.55000000000001%
# Validation: Loss at epoch 110 is 0.4991847351193428 and accuracy is 80.4%
# Train: Loss at epoch 111 is 0.4280854118987918 and accuracy is 88.4%
# Validation: Loss at epoch 111 is 0.5003315806388855 and accuracy is 80.0%
# Train: Loss at epoch 112 is 0.4194187354296446 and accuracy is 89.05%
# Validation: Loss at epoch 112 is 0.49462003260850906 and accuracy is 81.0%
# Train: Loss at epoch 113 is 0.4296324858441949 and accuracy is 87.9%
# Validation: Loss at epoch 113 is 0.48669280111789703 and accuracy is 81.8%
# Train: Loss at epoch 114 is 0.4360224111005664 and accuracy is 87.55%
# Validation: Loss at epoch 114 is 0.4964184798300266 and accuracy is 81.39999999999999%
# Train: Loss at epoch 115 is 0.43451553862541914 and accuracy is 87.25%
# Validation: Loss at epoch 115 is 0.4988800138235092 and accuracy is 80.4%
# Train: Loss at epoch 116 is 0.4280707687139511 and accuracy is 87.94999999999999%
# Validation: Loss at epoch 116 is 0.48967279493808746 and accuracy is 81.39999999999999%
# Train: Loss at epoch 117 is 0.4221226656809449 and accuracy is 88.14999999999999%
# Validation: Loss at epoch 117 is 0.47960731759667397 and accuracy is 82.19999999999999%
# Train: Loss at epoch 118 is 0.4271232234314084 and accuracy is 88.14999999999999%
# Validation: Loss at epoch 118 is 0.46797117218375206 and accuracy is 84.0%
# Train: Loss at epoch 119 is 0.4412523526698351 and accuracy is 86.75%
# Validation: Loss at epoch 119 is 0.48669422045350075 and accuracy is 82.0%
# Train: Loss at epoch 120 is 0.4286532960832119 and accuracy is 87.8%
# Validation: Loss at epoch 120 is 0.4951563701033592 and accuracy is 81.8%
# Train: Loss at epoch 121 is 0.4196237809956074 and accuracy is 88.94999999999999%
# Validation: Loss at epoch 121 is 0.48344243317842484 and accuracy is 81.6%
# Train: Loss at epoch 122 is 0.4208425171673298 and accuracy is 88.75%
# Validation: Loss at epoch 122 is 0.47570451721549034 and accuracy is 83.6%
# Train: Loss at epoch 123 is 0.42404935974627733 and accuracy is 88.9%
# Validation: Loss at epoch 123 is 0.49214768782258034 and accuracy is 81.2%
# Train: Loss at epoch 124 is 0.4345281468704343 and accuracy is 87.45%
# Validation: Loss at epoch 124 is 0.49370524287223816 and accuracy is 80.4%
# Train: Loss at epoch 125 is 0.44024421367794275 and accuracy is 86.65%
# Validation: Loss at epoch 125 is 0.4900621734559536 and accuracy is 81.6%
# Train: Loss at epoch 126 is 0.41670883633196354 and accuracy is 89.3%
# Validation: Loss at epoch 126 is 0.4704193063080311 and accuracy is 83.39999999999999%
# Train: Loss at epoch 127 is 0.4215774182230234 and accuracy is 88.7%
# Validation: Loss at epoch 127 is 0.4952458329498768 and accuracy is 81.39999999999999%
# Train: Loss at epoch 128 is 0.4207950532436371 and accuracy is 88.9%
# Validation: Loss at epoch 128 is 0.4936987869441509 and accuracy is 81.39999999999999%
# Train: Loss at epoch 129 is 0.4265081798657775 and accuracy is 88.3%
# Validation: Loss at epoch 129 is 0.47798049822449684 and accuracy is 82.8%
# Train: Loss at epoch 130 is 0.4232244584709406 and accuracy is 88.4%
# Validation: Loss at epoch 130 is 0.5018940344452858 and accuracy is 80.60000000000001%
# Train: Loss at epoch 131 is 0.41927468683570623 and accuracy is 88.85%
# Validation: Loss at epoch 131 is 0.47478102147579193 and accuracy is 83.0%
# Train: Loss at epoch 132 is 0.41365439537912607 and accuracy is 89.85%
# Validation: Loss at epoch 132 is 0.5965538173913956 and accuracy is 70.8%
# Train: Loss at epoch 133 is 0.4299247385933995 and accuracy is 87.64999999999999%
# Validation: Loss at epoch 133 is 0.48081398382782936 and accuracy is 81.39999999999999%
# Train: Loss at epoch 134 is 0.42577641550451517 and accuracy is 88.25%
# Validation: Loss at epoch 134 is 0.5032731033861637 and accuracy is 80.2%
# Train: Loss at epoch 135 is 0.4247337458655238 and accuracy is 88.85%
# Validation: Loss at epoch 135 is 0.4828014560043812 and accuracy is 82.6%
# Train: Loss at epoch 136 is 0.4211946167051792 and accuracy is 89.1%
# Validation: Loss at epoch 136 is 0.49613144621253014 and accuracy is 80.0%
# Train: Loss at epoch 137 is 0.42076968401670456 and accuracy is 89.14999999999999%
# Validation: Loss at epoch 137 is 0.4665575884282589 and accuracy is 84.8%
# Train: Loss at epoch 138 is 0.4115907959640026 and accuracy is 89.95%
# Validation: Loss at epoch 138 is 0.4896906316280365 and accuracy is 82.0%
# Train: Loss at epoch 139 is 0.4256530851125717 and accuracy is 88.55%
# Validation: Loss at epoch 139 is 0.4906684346497059 and accuracy is 81.39999999999999%
# Train: Loss at epoch 140 is 0.42843031603842974 and accuracy is 89.05%
# Validation: Loss at epoch 140 is 0.47101880237460136 and accuracy is 83.6%
# Train: Loss at epoch 141 is 0.41921637672930956 and accuracy is 89.0%
# Validation: Loss at epoch 141 is 0.48427465930581093 and accuracy is 82.39999999999999%
# Train: Loss at epoch 142 is 0.4179279822856188 and accuracy is 89.1%
# Validation: Loss at epoch 142 is 0.47136642783880234 and accuracy is 83.6%
# Train: Loss at epoch 143 is 0.4028634373098612 and accuracy is 91.25%
# Validation: Loss at epoch 143 is 0.4853087067604065 and accuracy is 81.2%
# Train: Loss at epoch 144 is 0.4121692515909672 and accuracy is 89.8%
# Validation: Loss at epoch 144 is 0.5113908685743809 and accuracy is 78.8%
# Train: Loss at epoch 145 is 0.42340977396816015 and accuracy is 88.94999999999999%
# Validation: Loss at epoch 145 is 0.46015963330864906 and accuracy is 85.2%
# Train: Loss at epoch 146 is 0.42373042088001966 and accuracy is 88.5%
# Validation: Loss at epoch 146 is 0.49196041002869606 and accuracy is 81.0%
# Train: Loss at epoch 147 is 0.4244999950751662 and accuracy is 88.0%
# Validation: Loss at epoch 147 is 0.4717344045639038 and accuracy is 83.39999999999999%
# Train: Loss at epoch 148 is 0.42657823115587234 and accuracy is 88.1%
# Validation: Loss at epoch 148 is 0.47671087086200714 and accuracy is 83.8%
# Train: Loss at epoch 149 is 0.4221503371372819 and accuracy is 88.55%
# Validation: Loss at epoch 149 is 0.4956619217991829 and accuracy is 80.60000000000001%
# Train: Loss at epoch 150 is 0.4123570844531059 and accuracy is 90.3%
# Validation: Loss at epoch 150 is 0.46827660873532295 and accuracy is 84.0%

# %%
# Step 7: Show results
plt.figure(1)
plt.plot(train_loss)
plt.plot(val_loss)
plt.title("Loss in training and validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])

plt.figure(2)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title("Accuracy in training and validation")
plt.xlabel("Epochs")
plt.ylabel("Acuracy (%)")
plt.legend(["Train", "Validation"])

plt.show()

# %%
# Step 7: Show results
plt.figure(1)
plt.plot(train_loss)
plt.plot(val_loss)
plt.title("Loss in training and validation")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train", "Validation"])

plt.figure(2)
plt.plot(train_acc)
plt.plot(val_acc)
plt.title("Accuracy in training and validation")
plt.xlabel("Epochs")
plt.ylabel("Acuracy (%)")
plt.legend(["Train", "Validation"])

plt.show()
